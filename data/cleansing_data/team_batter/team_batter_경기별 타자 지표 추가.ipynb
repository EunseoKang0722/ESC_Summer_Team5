# %%
import numpy as np
import pandas as pd

# %%
#타자 지표에 쓰일 계수들은 STATIZ사이트에서 크롤링해서 사용
import requests
from bs4 import BeautifulSoup

req = requests.get('http://www.statiz.co.kr/constant.php')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('body > div.wrapper > div.content-wrapper > div > section.content > div > div.col-md-12.col-xs-12.col-sm-12.col-lg-9 > div > div > div > div.box-body.no-padding.table-responsive > table')
table = tables[0]

table_html=str(table)
table_df_list=pd.read_html(table_html)
table_df = table_df_list[0]

idx = table_df.loc[0:4, ['연도', 'wBB','wHBP','w1B','w2B','w3B','wHR']]
idx.rename(columns = {'연도':'GYEAR'}, inplace = True)

idx
# Out:
#    GYEAR    wBB   wHBP    w1B    w2B    w3B    wHR
# 0   2020  0.729  0.758  0.936  1.280  1.590  1.951
# 1   2019  0.721  0.752  0.945  1.317  1.653  2.074
# 2   2018  0.726  0.753  0.920  1.242  1.533  1.857
# 3   2017  0.728  0.756  0.927  1.259  1.558  1.901
# 4   2016  0.747  0.774  0.944  1.273  1.569  1.898

# %%
    data = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2016.csv')
    data['H1']= data['HIT']- data['H2'] - data['H3'] - data['HR']
    data.loc[data['G_ID'].str.contains('2016'), 'GYEAR'] = 2016
    data = pd.merge(data, idx, on='GYEAR')
    data= data.drop('GYEAR', axis=1 )
    
    
    data['AVG'] = data['HIT']/ data['AB']
    data['SLG'] = (data['H1']+ 2 * data['H2']+ 3 * data['H3'] + 4 *data['HR']) / data['AB']
    data['IsoP']= data['SLG']- data['AVG']               
    data['OBP']= (data['HIT'] + data['BB'] + data['HP'])/(data['AB']+data['BB']+data['HP']+data['SF'])
    data['OPS'] = data['OBP']+ data['SLG']
    data['RC']= ((data['HIT']+ data['BB']+ data['HP']-data['CS']-data['GD']) * ((data['H1']+ 2 * data['H2'] + 3 * data['H3'] + 4 * data['HR']) +0.52 * (data['SB']+data['SH']+data['SF'])
                                                                                + 0.26 * (data['BB']+ data['HP'] -data['IB'])))/(data['AB']+data['BB']+data['HP']+data['SH']+data['SF'])
    data['XR']= 0.5*data['H1'] + 0.72*data['H2']+ 1.04 *data['H3'] + 1.44 *data['HR'] + 0.34* (data['HP']+data['BB']-data['IB'])+ 0.25* data['IB'] + 0.18 * data['SB'] - 0.32*data['CS'] -  0.09 * (data['AB'] -data['HIT']-data['KK']) - 0.098 * data['KK'] -0.37 *data['GD'] + 0.37* data['SF']+ 0.04* data['SH']
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+ data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['AB']+data['BB']-data['IB']+ data['SF']+ data['HP'])
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+
                   data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['PA']-data['IB'])
    data['BABIP']= (data['HIT'] - data['HR']) / (data['AB']-data['KK']-data['HR']+data['SF'])
    
    
    
    data = data.replace([np.nan, np.inf, -np.inf], 0)
    data.to_csv('team_batter_경기별_2016.csv', index=False)

# %%
    data = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2017.csv')
    data['H1']= data['HIT']- data['H2'] - data['H3'] - data['HR']
    data.loc[data['G_ID'].str.contains('2017'), 'GYEAR'] = 2017
    data = pd.merge(data, idx, on='GYEAR')
    data= data.drop('GYEAR', axis=1 )
    
    
    data['AVG'] = data['HIT']/ data['AB']
    data['SLG'] = (data['H1']+ 2 * data['H2']+ 3 * data['H3'] + 4 *data['HR']) / data['AB']
    data['IsoP']= data['SLG']- data['AVG']               
    data['OBP']= (data['HIT'] + data['BB'] + data['HP'])/(data['AB']+data['BB']+data['HP']+data['SF'])
    data['OPS'] = data['OBP']+ data['SLG']
    data['RC']= ((data['HIT']+ data['BB']+ data['HP']-data['CS']-data['GD']) * ((data['H1']+ 2 * data['H2'] + 3 * data['H3'] + 4 * data['HR']) +0.52 * (data['SB']+data['SH']+data['SF'])
                                                                                + 0.26 * (data['BB']+ data['HP'] -data['IB'])))/(data['AB']+data['BB']+data['HP']+data['SH']+data['SF'])
    data['XR']= 0.5*data['H1'] + 0.72*data['H2']+ 1.04 *data['H3'] + 1.44 *data['HR'] + 0.34* (data['HP']+data['BB']-data['IB'])+ 0.25* data['IB'] + 0.18 * data['SB'] - 0.32*data['CS'] -  0.09 * (data['AB'] -data['HIT']-data['KK']) - 0.098 * data['KK'] -0.37 *data['GD'] + 0.37* data['SF']+ 0.04* data['SH']
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+ data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['AB']+data['BB']-data['IB']+ data['SF']+ data['HP'])
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+
                   data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['PA']-data['IB'])
    data['BABIP']= (data['HIT'] - data['HR']) / (data['AB']-data['KK']-data['HR']+data['SF'])
    
    
    
    data = data.replace([np.nan, np.inf, -np.inf], 0)
    data.to_csv('team_batter_경기별_2017.csv', index=False)

# %%
    data = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2018.csv')
    data['H1']= data['HIT']- data['H2'] - data['H3'] - data['HR']
    data.loc[data['G_ID'].str.contains('2018'), 'GYEAR'] = 2018
    data = pd.merge(data, idx, on='GYEAR')
    data= data.drop('GYEAR', axis=1 )
    
    
    data['AVG'] = data['HIT']/ data['AB']
    data['SLG'] = (data['H1']+ 2 * data['H2']+ 3 * data['H3'] + 4 *data['HR']) / data['AB']
    data['IsoP']= data['SLG']- data['AVG']               
    data['OBP']= (data['HIT'] + data['BB'] + data['HP'])/(data['AB']+data['BB']+data['HP']+data['SF'])
    data['OPS'] = data['OBP']+ data['SLG']
    data['RC']= ((data['HIT']+ data['BB']+ data['HP']-data['CS']-data['GD']) * ((data['H1']+ 2 * data['H2'] + 3 * data['H3'] + 4 * data['HR']) +0.52 * (data['SB']+data['SH']+data['SF'])
                                                                                + 0.26 * (data['BB']+ data['HP'] -data['IB'])))/(data['AB']+data['BB']+data['HP']+data['SH']+data['SF'])
    data['XR']= 0.5*data['H1'] + 0.72*data['H2']+ 1.04 *data['H3'] + 1.44 *data['HR'] + 0.34* (data['HP']+data['BB']-data['IB'])+ 0.25* data['IB'] + 0.18 * data['SB'] - 0.32*data['CS'] -  0.09 * (data['AB'] -data['HIT']-data['KK']) - 0.098 * data['KK'] -0.37 *data['GD'] + 0.37* data['SF']+ 0.04* data['SH']
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+ data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['AB']+data['BB']-data['IB']+ data['SF']+ data['HP'])
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+
                   data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['PA']-data['IB'])
    data['BABIP']= (data['HIT'] - data['HR']) / (data['AB']-data['KK']-data['HR']+data['SF'])
    
    
    
    data = data.replace([np.nan, np.inf, -np.inf], 0)
    data.to_csv('team_batter_경기별_2018.csv', index=False)

# %%
    data = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2019.csv')
    data['H1']= data['HIT']- data['H2'] - data['H3'] - data['HR']
    data.loc[data['G_ID'].str.contains('2019'), 'GYEAR'] = 2019
    data = pd.merge(data, idx, on='GYEAR')
    data= data.drop('GYEAR', axis=1 )
    
    
    data['AVG'] = data['HIT']/ data['AB']
    data['SLG'] = (data['H1']+ 2 * data['H2']+ 3 * data['H3'] + 4 *data['HR']) / data['AB']
    data['IsoP']= data['SLG']- data['AVG']               
    data['OBP']= (data['HIT'] + data['BB'] + data['HP'])/(data['AB']+data['BB']+data['HP']+data['SF'])
    data['OPS'] = data['OBP']+ data['SLG']
    data['RC']= ((data['HIT']+ data['BB']+ data['HP']-data['CS']-data['GD']) * ((data['H1']+ 2 * data['H2'] + 3 * data['H3'] + 4 * data['HR']) +0.52 * (data['SB']+data['SH']+data['SF'])
                                                                                + 0.26 * (data['BB']+ data['HP'] -data['IB'])))/(data['AB']+data['BB']+data['HP']+data['SH']+data['SF'])
    data['XR']= 0.5*data['H1'] + 0.72*data['H2']+ 1.04 *data['H3'] + 1.44 *data['HR'] + 0.34* (data['HP']+data['BB']-data['IB'])+ 0.25* data['IB'] + 0.18 * data['SB'] - 0.32*data['CS'] -  0.09 * (data['AB'] -data['HIT']-data['KK']) - 0.098 * data['KK'] -0.37 *data['GD'] + 0.37* data['SF']+ 0.04* data['SH']
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+ data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['AB']+data['BB']-data['IB']+ data['SF']+ data['HP'])
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+
                   data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['PA']-data['IB'])
    data['BABIP']= (data['HIT'] - data['HR']) / (data['AB']-data['KK']-data['HR']+data['SF'])
    
    
    
    data = data.replace([np.nan, np.inf, -np.inf], 0)
    data.to_csv('team_batter_경기별_2019.csv', index=False)

# %%
    data = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2020.csv')
    data['H1']= data['HIT']- data['H2'] - data['H3'] - data['HR']
    data.loc[data['G_ID'].str.contains('2020'), 'GYEAR'] = 2020
    data = pd.merge(data, idx, on='GYEAR')
    data= data.drop('GYEAR', axis=1 )
    
    
    data['AVG'] = data['HIT']/ data['AB']
    data['SLG'] = (data['H1']+ 2 * data['H2']+ 3 * data['H3'] + 4 *data['HR']) / data['AB']
    data['IsoP']= data['SLG']- data['AVG']               
    data['OBP']= (data['HIT'] + data['BB'] + data['HP'])/(data['AB']+data['BB']+data['HP']+data['SF'])
    data['OPS'] = data['OBP']+ data['SLG']
    data['RC']= ((data['HIT']+ data['BB']+ data['HP']-data['CS']-data['GD']) * ((data['H1']+ 2 * data['H2'] + 3 * data['H3'] + 4 * data['HR']) +0.52 * (data['SB']+data['SH']+data['SF'])
                                                                                + 0.26 * (data['BB']+ data['HP'] -data['IB'])))/(data['AB']+data['BB']+data['HP']+data['SH']+data['SF'])
    data['XR']= 0.5*data['H1'] + 0.72*data['H2']+ 1.04 *data['H3'] + 1.44 *data['HR'] + 0.34* (data['HP']+data['BB']-data['IB'])+ 0.25* data['IB'] + 0.18 * data['SB'] - 0.32*data['CS'] -  0.09 * (data['AB'] -data['HIT']-data['KK']) - 0.098 * data['KK'] -0.37 *data['GD'] + 0.37* data['SF']+ 0.04* data['SH']
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+ data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['AB']+data['BB']-data['IB']+ data['SF']+ data['HP'])
    data['wOBA']= (data['wBB'] * (data['BB']-data['IB']) + data['wHBP']*data['HP'] + data['w1B']*data['H1']+
                   data['w2B']* data['H2'] + data['w3B'] * data['H3'] +data['wHR']*data['HR'])/(data['PA']-data['IB'])
    data['BABIP']= (data['HIT'] - data['HR']) / (data['AB']-data['KK']-data['HR']+data['SF'])
    
    
    
    data = data.replace([np.nan, np.inf, -np.inf], 0)
    data.to_csv('team_batter_경기별_2020.csv', index=False)
