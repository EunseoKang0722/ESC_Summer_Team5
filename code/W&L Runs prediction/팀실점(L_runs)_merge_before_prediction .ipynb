# %%
import numpy as np
import pandas as pd

# %%
pitcher= pd.read_csv('pitcher_scaled_revised.csv')
hitter= pd.read_csv('hitter_scaled.csv')

# %%
pitcher.head()
# Out:
#    Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID  CG_CK WLS  HOLD  INN2  \
# 0           0  20160401HHLG0  20160401   LG      HH      0   W     0    36
# 1           1  20160401HHLG0  20160401   HH      LG      0   L     0    34
# 2           2  20160401HTNC0  20160401   NC      HT      0   W     0    27
# 3           3  20160401HTNC0  20160401   HT      NC      0   L     0    24
# 4           4  20160401KTSK0  20160401   SK      KT      0   L     0    27
#
#     BF  ...  P2_WHIP_RT  CB_WHIP_RT      K/BB      OOPS      WHIP     BABIP  \
# 0  184  ...    0.061224    0.200000  0.238095  0.652618  0.295302  0.361111
# 1  196  ...    0.047619    0.062500  0.196429  0.615942  0.250296  0.266667
# 2  143  ...    0.049451    0.178571  0.238095  0.727554  0.268456  0.304348
# 3  147  ...    0.080745    0.156250  0.128571  0.966667  0.395973  0.368421
# 4  151  ...    0.112245    0.187500  0.125000  0.853175  0.375839  0.321429
#
#        kFIP  HEADER_NO_1  HEADER_NO_2  TB_SC_T
# ...

# %%
hitter.head()
# Out:
#    Unnamed: 0           G_ID   GDAY_DS T_ID VS_T_ID        PA        AB  RBI  \
# 0           0  20160401HHLG0  20160401   HH      LG  0.729167  0.884615    4
# 1           1  20160402HHLG0  20160402   HH      LG  0.687500  0.860000    7
# 2           2  20160405WOHH0  20160405   HH      WO  0.500000  0.853659    8
# 3           3  20160406WOHH0  20160406   HH      WO  0.395833  0.972222    4
# 4           4  20160407WOHH0  20160407   HH      WO  0.479167  0.975000    3
#
#    RUN       HIT  ...  P_HRA_RT  P_AB_CN  P_HIT_CN      IsoP       OPS  \
# 0    4  0.250000  ...  0.200000       15         3  0.043478  0.652618
# 1    7  0.260000  ...  0.333333       15         5  0.093023  0.770349
# 2    9  0.317073  ...  0.428571       14         6  0.114286  0.924739
# 3    4  0.305556  ...  0.222222        9         2  0.257143  0.885714
# 4    3  0.300000  ...  0.181818       11         2  0.205128  0.837821
#
#          XR     BABIP  HEADER_NO_1  HEADER_NO_2  TB_SC_T
# ...

# %%
pitcher=pitcher.drop(['Unnamed: 0'],axis=1)
hitter=hitter.drop(['Unnamed: 0'],axis=1)

# %%
pitcher.columns
# Out:
# Index(['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'CG_CK', 'WLS', 'HOLD', 'INN2',
#        'BF', 'PA', 'AB', 'HIT', 'H1', 'H2', 'H3', 'HR', 'SB', 'CS', 'SH', 'SF',
#        'BB', 'IB', 'HP', 'KK', 'GD', 'WP', 'BK', 'ERR', 'R', 'ER', 'P_WHIP_RT',
#        'P2_WHIP_RT', 'CB_WHIP_RT', 'K/BB', 'OOPS', 'WHIP', 'BABIP', 'kFIP',
#        'HEADER_NO_1', 'HEADER_NO_2', 'TB_SC_T'],
#       dtype='object')

# %%
hitter.columns
# Out:
# Index(['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'PA', 'AB', 'RBI', 'RUN', 'HIT',
#        'H1', 'H2', 'H3', 'HR', 'SB', 'CS', 'SH', 'SF', 'BB', 'IB', 'HP', 'KK',
#        'GD', 'ERR', 'LOB', 'P_HRA_RT', 'P_AB_CN', 'P_HIT_CN', 'IsoP', 'OPS',
#        'XR', 'BABIP', 'HEADER_NO_1', 'HEADER_NO_2', 'TB_SC_T'],
#       dtype='object')

# %%
hitter_ERR=hitter[['G_ID', 'GDAY_DS', 'T_ID','ERR']]
hitter_ERR.columns=['G_ID', 'GDAY_DS', 'T_ID','Hitter_ERR']

# %%
pitcher.columns=['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'CG_CK', 'WLS', 'HOLD', 'INN2',
       'BF', 'PA', 'AB', 'HIT', 'H1', 'H2', 'H3', 'HR', 'SB', 'CS', 'SH', 'SF',
       'BB', 'IB', 'HP', 'KK', 'GD', 'WP', 'BK', 'Pitcher_ERR', 'R', 'ER', 'P_WHIP_RT',
       'P2_WHIP_RT', 'CB_WHIP_RT', 'K/BB', 'OOPS', 'WHIP', 'BABIP', 'kFIP',
       'HEADER_NO_1', 'HEADER_NO_2', 'TB_SC_T']

# %%
L_runs=pd.merge(pitcher,hitter_ERR)

# %%
L_runs
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  CG_CK WLS  HOLD  INN2   BF  \
# 0     20160401HHLG0  20160401   LG      HH      0   W     0    36  184
# 1     20160401HHLG0  20160401   HH      LG      0   L     0    34  196
# 2     20160401HTNC0  20160401   NC      HT      0   W     0    27  143
# 3     20160401HTNC0  20160401   HT      NC      0   L     0    24  147
# 4     20160401KTSK0  20160401   SK      KT      0   L     0    27  151
# ...             ...       ...  ...     ...    ...  ..   ...   ...  ...
# 6395  20200719LTSS0  20200719   LT      SS      0   W     2    27  155
# 6396  20200719OBHT0  20200719   HT      OB      0   L     0    27  137
# 6397  20200719OBHT0  20200719   OB      HT      0   W     1    27  177
# 6398  20200719WOSK0  20200719   SK      WO      0   W     0    27  134
# 6399  20200719WOSK0  20200719   WO      SK      0   L     2    24  173
#
#             PA  ...  CB_WHIP_RT      K/BB      OOPS      WHIP     BABIP  \
# ...

# %%
L_runs.to_csv('L_runs.csv',index=False)

# %%
L_runs.columns
# Out:
# Index(['G_ID', 'GDAY_DS', 'T_ID', 'VS_T_ID', 'CG_CK', 'WLS', 'HOLD', 'INN2',
#        'BF', 'PA', 'AB', 'HIT', 'H1', 'H2', 'H3', 'HR', 'SB', 'CS', 'SH', 'SF',
#        'BB', 'IB', 'HP', 'KK', 'GD', 'WP', 'BK', 'Pitcher_ERR', 'R', 'ER',
#        'P_WHIP_RT', 'P2_WHIP_RT', 'CB_WHIP_RT', 'K/BB', 'OOPS', 'WHIP',
#        'BABIP', 'kFIP', 'HEADER_NO_1', 'HEADER_NO_2', 'TB_SC_T', 'Hitter_ERR'],
#       dtype='object')
